# %%
import pandas as pd

# %%
data=pd.read_csv("all.csv")

# %%
data
# Out:
#      S.N        Date  Nepse  C Banking  Dev Banking  Finance  Micro- Finance  \
# 0      1    1/1/2024  -0.42       0.01         0.10    -0.80           -0.15
# 1      2    1/2/2024  -1.45      -1.15        -1.35    -1.35           -1.30
# 2      3    1/3/2024   1.37       0.35         1.12     1.78            0.57
# 3      4    1/4/2024  -0.42      -0.54        -0.82    -0.91           -0.30
# 4      5    1/7/2024  -1.28      -1.81        -1.18    -1.38           -0.45
# ..   ...         ...    ...        ...          ...      ...             ...
# 225  226  12/19/2024  -1.19      -0.82        -1.25    -2.31           -0.71
# 226  227  12/22/2024  -0.52      -0.87        -2.05    -1.49           -0.39
# 227  228  12/23/2024   1.11       0.84         1.15     1.67            0.81
# 228  229  12/24/2024   0.54       0.76         1.75     1.62            0.95
# 229  230  12/26/2024   0.15       1.81        -2.48    -2.70            0.14
#
# ...

# %%
data=data.drop('S.N',axis=1)

# %%
data
# Out:
#            Date  Nepse  C Banking  Dev Banking  Finance  Micro- Finance  \
# 0      1/1/2024  -0.42       0.01         0.10    -0.80           -0.15
# 1      1/2/2024  -1.45      -1.15        -1.35    -1.35           -1.30
# 2      1/3/2024   1.37       0.35         1.12     1.78            0.57
# 3      1/4/2024  -0.42      -0.54        -0.82    -0.91           -0.30
# 4      1/7/2024  -1.28      -1.81        -1.18    -1.38           -0.45
# ..          ...    ...        ...          ...      ...             ...
# 225  12/19/2024  -1.19      -0.82        -1.25    -2.31           -0.71
# 226  12/22/2024  -0.52      -0.87        -2.05    -1.49           -0.39
# 227  12/23/2024   1.11       0.84         1.15     1.67            0.81
# 228  12/24/2024   0.54       0.76         1.75     1.62            0.95
# 229  12/26/2024   0.15       1.81        -2.48    -2.70            0.14
#
#      Investment  Life- Insurance  Non-life insurance  Hotels  Others  Trading  \
# ...

# %%
data.columns
# Out:
# Index(['Date', 'Nepse', 'C Banking', 'Dev Banking', 'Finance',
#        'Micro- Finance', 'Investment', 'Life- Insurance', 'Non-life insurance',
#        'Hotels', 'Others', 'Trading', 'Manufacture', 'Hydropower'],
#       dtype='object')

# %%
Nepse=data[['Date','Nepse']]
cbank=data[['Date','C Banking']]
dbank=data[['Date','Dev Banking']]
fin=data[['Date','Finance']]
mic=data[['Date','Micro- Finance']]
invest=data[['Date','Investment']]
life=data[['Date','Life- Insurance']]
nonlife=data[['Date','Non-life insurance']]
hotel=data[['Date','Hotels']]
other=data[['Date','Others']]
trad=data[['Date','Trading']]
manu=data[['Date','Manufacture']]
hydro=data[['Date','Hydropower']]

# %%
# Out:
#            Date  Nepse
# 0      1/1/2024  -0.42
# 1      1/2/2024  -1.45
# 2      1/3/2024   1.37
# 3      1/4/2024  -0.42
# 4      1/7/2024  -1.28
# ..          ...    ...
# 225  12/19/2024  -1.19
# 226  12/22/2024  -0.52
# 227  12/23/2024   1.11
# 228  12/24/2024   0.54
# 229  12/26/2024   0.15
#
# [230 rows x 2 columns]
